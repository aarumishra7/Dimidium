# %% [markdown]
# <a href="https://colab.research.google.com/github/aarumishra7/Dimidium/blob/main/Dimidium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import warnings
import math
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
import seaborn as sns
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
x_train = pd.read_csv('/content/exoTrain.csv')
y_test = pd.read_csv('/content/exoTest.csv')
x_train.head(7)
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
# 5      2   211.10   163.57   179.16   187.82   188.46   168.13  203.46
# 6      2     9.34    49.96    33.30     9.63    37.64    20.85    4.54
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
# 5   178.65  166.49  ...     -98.45      30.34      30.34      29.62
# 6    22.42   10.11  ...     -58.56       9.93       9.93      23.50
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      48.57      92.54      39.32      61.42       5.08     -39.54
# 1      -4.86       0.76     -11.70       6.46      16.00      19.93
# 2     -20.88       5.06     -11.80     -28.91     -70.02     -96.67
# 3      20.03     -12.67      -8.77     -17.31     -17.35      13.98
# 4    -443.76    -438.54    -399.71    -384.65    -411.79    -510.54
# 5      28.80      19.27     -43.90     -41.63     -52.90     -16.16
# 6       5.28      -0.44      10.90     -11.77      -9.25     -36.69
#
# [7 rows x 3198 columns]

# %%
label_mapping = {2: 1, 1: 0}
x_train['LABEL'] = [label_mapping[item] for item in x_train['LABEL']]
y_test['LABEL'] = [label_mapping[item] for item in y_test['LABEL']]

# %%
x_train.describe()
# Out:
#              LABEL        FLUX.1        FLUX.2        FLUX.3        FLUX.4  \
# count  5087.000000  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03
# mean      0.007273  1.445054e+02  1.285778e+02  1.471348e+02  1.561512e+02
# std       0.084982  2.150669e+04  2.179717e+04  2.191309e+04  2.223366e+04
# min       0.000000 -2.278563e+05 -3.154408e+05 -2.840018e+05 -2.340069e+05
# 25%       0.000000 -4.234000e+01 -3.952000e+01 -3.850500e+01 -3.505000e+01
# 50%       0.000000 -7.100000e-01 -8.900000e-01 -7.400000e-01 -4.000000e-01
# 75%       0.000000  4.825500e+01  4.428500e+01  4.232500e+01  3.976500e+01
# max       1.000000  1.439240e+06  1.453319e+06  1.468429e+06  1.495750e+06
#
#              FLUX.5        FLUX.6        FLUX.7        FLUX.8        FLUX.9  \
# count  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03
# mean   1.561477e+02  1.469646e+02  1.168380e+02  1.144983e+02  1.228639e+02
# std    2.308448e+04  2.410567e+04  2.414109e+04  2.290691e+04  2.102681e+04
# min   -4.231956e+05 -5.975521e+05 -6.724046e+05 -5.790136e+05 -3.973882e+05
# 25%   -3.195500e+01 -3.338000e+01 -2.813000e+01 -2.784000e+01 -2.683500e+01
# 50%   -6.100000e-01 -1.030000e+00 -8.700000e-01 -6.600000e-01 -5.600000e-01
# 75%    3.975000e+01  3.514000e+01  3.406000e+01  3.170000e+01  3.045500e+01
# max    1.510937e+06  1.508152e+06  1.465743e+06  1.416827e+06  1.342888e+06
#
#        ...     FLUX.3188     FLUX.3189     FLUX.3190     FLUX.3191  \
# count  ...  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03
# mean   ...  3.485578e+02  4.956476e+02  6.711211e+02  7.468790e+02
# std    ...  2.864786e+04  3.551876e+04  4.349963e+04  4.981375e+04
# min    ... -3.240480e+05 -3.045540e+05 -2.933140e+05 -2.838420e+05
# 25%    ... -1.760000e+01 -1.948500e+01 -1.757000e+01 -2.076000e+01
# 50%    ...  2.600000e+00  2.680000e+00  3.050000e+00  3.590000e+00
# 75%    ...  2.211000e+01  2.235000e+01  2.639500e+01  2.909000e+01
# max    ...  1.779338e+06  2.379227e+06  2.992070e+06  3.434973e+06
#
#           FLUX.3192     FLUX.3193      FLUX.3194      FLUX.3195  \
# count  5.087000e+03  5.087000e+03    5087.000000    5087.000000
# mean   6.937372e+02  6.553031e+02    -494.784966    -544.594264
# std    5.087103e+04  5.339979e+04   17844.469520   17722.339334
# min   -3.288214e+05 -5.028894e+05 -775322.000000 -732006.000000
# 25%   -2.226000e+01 -2.440500e+01     -26.760000     -24.065000
# 50%    3.230000e+00  3.500000e+00      -0.680000       0.360000
# 75%    2.780000e+01  3.085500e+01      18.175000      18.770000
# max    3.481220e+06  3.616292e+06  288607.500000  215972.000000
#
#            FLUX.3196      FLUX.3197
# count    5087.000000    5087.000000
# mean     -440.239100    -300.536399
# std     16273.406292   14459.795577
# min   -700992.000000 -643170.000000
# 25%       -21.135000     -19.820000
# 50%         0.900000       1.430000
# 75%        19.465000      20.280000
# max    207590.000000  211302.000000
#
# [8 rows x 3198 columns]

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,8))
sns.countplot(x = 'LABEL', data=x_train, palette = "Set2", ax = ax[0])
ax[0].set_xlabel('')
x_train['LABEL'].value_counts().plot.pie(explode = [0,0.1], autopct ='%1.1f%%',ax = ax[1], shadow = True)
fig.suptitle('(0: Not Exoplanet || 1: Exoplanet)\n', fontsize = 24, fontweight = 'bold')
# Out:
# Text(0.5, 0.98, '(0: Not Exoplanet || 1: Exoplanet)\n')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(x_train.corr())
plt.title('Correlation in the data')
plt.show()

# %%
train_y=x_train[x_train['LABEL'] == 1]
train_n=x_train[x_train['LABEL'] < 1]
train_t_n=train_n.iloc[:,1:].T
train_t_y=train_y.iloc[:,1:].T
train_t_n.head()
# Out:
#           37     38      39      40      41      42     43      44      45    \
# FLUX.1 -141.22 -35.62  142.40 -167.02  207.74  174.65   9.71 -122.54  219.30
# FLUX.2  -81.79 -28.55  137.03 -137.65  223.60  167.49  16.51 -127.90  235.44
# FLUX.3  -52.28 -27.29   93.65 -150.05  246.15  169.56  12.25 -118.55  229.30
# FLUX.4  -32.45 -28.94  105.64 -136.85  224.06  191.28  13.08  -99.80  225.40
# FLUX.5   -1.55 -15.13   98.22  -98.73  210.77  192.23   9.25  -93.90  238.72
#
#            46    ...    5077   5078    5079   5080    5081   5082    5083  \
# FLUX.1 -3237.28  ...  125.57   7.45  475.61 -46.63  299.41 -91.91  989.75
# FLUX.2 -3261.75  ...   78.69  10.02  395.50 -55.39  302.77 -92.97  891.01
# FLUX.3 -3269.16  ...   98.29   6.87  423.61 -64.88  278.68 -78.76  908.53
# FLUX.4 -3297.16  ...   91.16  -2.82  376.36 -88.75  263.48 -97.33  851.83
# FLUX.5 -3289.84  ...   78.42  -1.56  338.94 -75.40  236.89 -68.00  755.11
#
#           5084  5085    5086
# FLUX.1  273.39  3.82  323.28
# FLUX.2  278.00  2.09  306.36
# FLUX.3  261.73 -3.29  293.16
# FLUX.4  236.99 -2.88  287.67
# FLUX.5  280.73  1.66  249.89
#
# [5 rows x 5050 columns]

# %%
fig = make_subplots(rows=2, cols=2,subplot_titles=("Flux variation of star 0", "Flux variation of star 1",
                                                   "Flux variation of star 35", "Flux variation of star 36"))
fig.add_trace(
    go.Scatter(y=train_t_y[0], x=train_t_y.index),
    row=1, col=1
)
fig.add_trace(
    go.Scatter(y=train_t_y[1], x=train_t_y.index),
    row=1, col=2
)
fig.add_trace(
    go.Scatter(y=train_t_y[35], x=train_t_y.index),
    row=2, col=1
)
fig.add_trace(
    go.Scatter(y=train_t_y[36], x=train_t_y.index),
    row=2, col=2
)
fig.update_layout(height=600, width=800, title_text="Exoplanets Stars examples",showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0edda24e-fbb3-4f87-a708-6164be500bf8" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0edda24e-fbb3-4f87-a708-6164be500bf8")) {                    Plotly.newPlot(                        "0edda24e-fbb3-4f87-a708-6164be500bf8",                        [{"x":["FLUX.1","FLUX.2","FLUX.3","FLUX.4","FLUX.5","FLUX.6","FLUX.7","FLUX.8","FLUX.9","FLUX.10","FLUX.11","FLUX.12","FLUX.13","FLUX.14","FLUX.15","FLUX.16","FLUX.17","FLUX.18","FLUX.19","FLUX.20","FLUX.21","FLUX.22","FLUX.23","FLUX.24","FLUX.25","FLUX.26","FLUX.27","FLUX.28","FLUX.29","FLUX.30","FLUX.31","FLUX.32","FLUX.33","FLUX.34","FLUX.35","FLUX.36","FLUX.37","FLUX.38","FLUX.39","FLUX.40","FLUX.41","FLUX.42","FLUX.43","FLUX.44","FLUX.45","FLUX.46","FLUX.47","FLUX.48","FLUX.49","FLUX.50","FLUX.51","FLUX.52","FLUX.53","FLUX.54","FLUX.55","FLUX.56","FLUX.57","FLUX.58","FLUX.59","FLUX.60","FLUX.61","FLUX.62","FLUX.63","FLUX.64","FLUX.65","FLUX.66","FLUX.67","FLUX.68","FLUX.69","FLUX.70","FLUX.71","FLUX.72","FLUX.73","FLUX.74","FLUX.75","FLUX.76","FLUX.77","FLUX.78","FLUX.79","FLUX.80","FLUX.81","FLUX.82","FLUX.83","FLUX.84","FLUX.85","FLUX.86","FLUX.87","FLUX.88","FLUX.89","FLUX.90","FLUX.91","FLUX.92","FLUX.93","FLUX.94","FLUX.95","FLUX.96","FLUX.97","FLUX.98","FLUX.99","FLUX.100","FLUX.101","FLUX.102","FLUX.103","FLUX.104","FLUX.105","FLUX.106","FLUX.107","FLUX.108","FLUX.109","FLUX.110","FLUX.111","FLUX.112","FLUX.113","FLUX.114","FLUX.115","FLUX.116","FLUX.117","FLUX.118","FLUX.119","FLUX.120","FLUX.121","FLUX.122","FLUX.123","FLUX.124","FLUX.125","FLUX.126","FLUX.127","FLUX.128","FLUX.129","FLUX.130","FLUX.131","FLUX.132","FLUX.133","FLUX.134","FLUX.135","FLUX.136","FLUX.137","FLUX.138","FLUX.139","FLUX.140","FLUX.141","FLUX.142","FLUX.143","FLUX.144","FLUX.145","FLUX.146","FLUX.147","FLUX.148","FLUX.149","FLUX.150","FLUX.151","FLUX.152","FLUX.153","FLUX.154","FLUX.155","FLUX.156","FLUX.157","FLUX.158","FLUX.159","FLUX.160","FLUX.161","FLUX.162","FLUX.163","FLUX.164","FLUX.165","FLUX.166","FLUX.167","FLUX.168","FLUX.169","FLUX.170","FLUX.171","FLUX.172","FLUX.173","FLUX.174","FLUX.175","FLUX.176","FLUX.177","FLUX.178","FLUX.179","FLUX.180","FLUX.181","FLUX.182","FLUX.183","FLUX.184","FLUX.185","FLUX.186","FLUX.187","FLUX.188","FLUX.189","FLUX.190","FLUX.191","FLUX.192","FLUX.193","FLUX.194","FLUX.195","FLUX.196","FLUX.197","FLUX.198","FLUX.199","FLUX.200","FLUX.201","FLUX.202","FLUX.203","FLUX.204","FLUX.205","FLUX.206","FLUX.207","FLUX.208","FLUX.209","FLUX.210","FLUX.211","FLUX.212","FLUX.213","FLUX.214","FLUX.215","FLUX.216","FLUX.217","FLUX.218","FLUX.219","FLUX.220","FLUX.221","FLUX.222","FLUX.223","FLUX.224","FLUX.225","FLUX.226","FLUX.227","FLUX.228","FLUX.229","FLUX.230","FLUX.231","FLUX.232","FLUX.233","FLUX.234","FLUX.235","FLUX.236","FLUX.237","FLUX.238","FLUX.239","FLUX.240","FLUX.241","FLUX.242","FLUX.243","FLUX.244","FLUX.245","FLUX.246","FLUX.247","FLUX.248","FLUX.249","FLUX.250","FLUX.251","FLUX.252","FLUX.253","FLUX.254","FLUX.255","FLUX.256","FLUX.257","FLUX.258","FLUX.259","FLUX.260","FLUX.261","FLUX.262","FLUX.263","FLUX.264","FLUX.265","FLUX.266","FLUX.267","FLUX.268","FLUX.269","FLUX.270","FLUX.271","FLUX.272","FLUX.273","FLUX.274","FLUX.275","FLUX.276","FLUX.277","FLUX.278","FLUX.279","FLUX.280","FLUX.281","FLUX.282","FLUX.283","FLUX.284","FLUX.285","FLUX.286","FLUX.287","FLUX.288","FLUX.289","FLUX.290","FLUX.291","FLUX.292","FLUX.293","FLUX.294","FLUX.295","FLUX.296","FLUX.297","FLUX.298","FLUX.299","FLUX.300","FLUX.301","FLUX.302","FLUX.303","FLUX.304","FLUX.305","FLUX.306","FLUX.307","FLUX.308","FLUX.309","FLUX.310","FLUX.311","FLUX.312","FLUX.313","FLUX.314","FLUX.315","FLUX.316","FLUX.317","FLUX.318","FLUX.319","FLUX.320","FLUX.321","FLUX. ...

# %%
from sklearn.preprocessing import StandardScaler
trainx=x_train.iloc[:,1:]
textx=y_test.iloc[:,1:]
scaler=StandardScaler()
train_scaled=scaler.fit_transform(trainx)
test_scaled=scaler.fit_transform(textx)

# %%
trainy=x_train[['LABEL']]
testy=y_test[['LABEL']]
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(train_scaled, trainy['LABEL'])
y_pred = svclassifier.predict(test_scaled)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(testy, y_pred))
print(classification_report(testy, y_pred))
# Out:
# [[556   9]
#  [  5   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       565
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       570
#    macro avg       0.50      0.49      0.49       570
# weighted avg       0.98      0.98      0.98       570

# %%
svclassifier = SVC(kernel='poly')
svclassifier.fit(train_scaled, trainy['LABEL'])
y_pred = svclassifier.predict(test_scaled)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(testy, y_pred))
print(classification_report(testy, y_pred))
# Out:
# [[565   0]
#  [  5   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       565
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570

# %%
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(train_scaled, trainy['LABEL'])
y_pred = svclassifier.predict(test_scaled)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(testy, y_pred))
print(classification_report(testy, y_pred))
# Out:
# [[565   0]
#  [  5   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       565
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570

# %%
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=6)
pca.fit(train_scaled)
PCA(n_components=6)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
trns_x=pca.transform(train_scaled)
trns_y=pca.transform(test_scaled)
testy
# Out:
# [0.27373539 0.22536219 0.14929127 0.09802696 0.05819974 0.04072856]
# [2109.92811427 1914.4441909  1558.18634093 1262.62663108  972.8876534
#   813.86372792]
#      LABEL
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 565      0
# 566      0
# 567      0
# 568      0
# 569      0
#
# [570 rows x 1 columns]

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
svclassifier.fit(trns_x, trainy['LABEL'])
y_pred = svclassifier.predict(trns_y)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(testy['LABEL'], y_pred))
print(classification_report(testy['LABEL'], y_pred))
# Out:
# [[565   0]
#  [  5   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       565
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570

# %%
trainy.loc[trainy['LABEL'] == 0, 'new1'] = 0
trainy.loc[trainy['LABEL'] > 0, 'new1'] = 1
testy.loc[testy['LABEL'] > 0, 'new1'] = 1
testy.loc[testy['LABEL'] == 0, 'new1'] = 0

# %%
import statsmodels.api as sm
logit_model=sm.Logit(trainy['new1'],trns_x)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.693147
#          Iterations 3
#                          Results: Logit
# ================================================================
# Model:              Logit            Method:           MLE
# Dependent Variable: new1             Pseudo R-squared: -15.098
# Date:               2023-11-30 17:33 AIC:              7064.0771
# No. Observations:   5087             BIC:              7103.2838
# Df Model:           5                Log-Likelihood:   -3526.0
# Df Residuals:       5081             LL-Null:          -219.04
# Converged:          1.0000           LLR p-value:      1.0000
# No. Iterations:     3.0000           Scale:            1.0000
# -------------------------------------------------------------------
#        Coef.     Std.Err.       z       P>|z|      [0.025    0.975]
# -------------------------------------------------------------------
# x1    -0.0000      0.0009    -0.0165    0.9868    -0.0019    0.0018
# x2    -0.0000      0.0010    -0.0013    0.9989    -0.0020    0.0020
# x3    -0.0000      0.0013    -0.0377    0.9699    -0.0026    0.0025
# x4    -0.0000      0.0016    -0.0241    0.9808    -0.0031    0.0031
# x5    -0.0000      0.0021    -0.0028    0.9978    -0.0040    0.0040
# x6    -0.0000      0.0025    -0.0036    0.9972    -0.0048    0.0048
# ================================================================

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(trns_x, trainy['new1'])
y_pred = logreg.predict(trns_y)
print('Accuracy of logistic regression classifier: {:.2f}'.format(logreg.score(trns_y, testy['new1'])))
# Out:
# Accuracy of logistic regression classifier: 0.99

# %%
from imblearn.over_sampling import SMOTE
over = SMOTE(random_state=0)
ov_train_x,ov_train_y=over.fit_resample(trns_x, trainy['new1'])
ov_train_y=ov_train_y.astype('int')
ov_train_y.value_counts()
# Out:
# 1    5050
# 0    5050
# Name: new1, dtype: int64

# %%
ov_train_y=ov_train_y.values.tolist()
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
svclassifier.fit(ov_train_x, ov_train_y)
y_pred = svclassifier.predict(trns_y)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(testy['new1'], y_pred))
print(classification_report(testy['new1'], y_pred))
# Out:
# [[552  13]
#  [  4   1]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98       565
#          1.0       0.07      0.20      0.11         5
#
#     accuracy                           0.97       570
#    macro avg       0.53      0.59      0.55       570
# weighted avg       0.98      0.97      0.98       570

# %%
import numpy as np
ov_train_y=np.array(ov_train_y)
ov_train_y.dtype
from sklearn.model_selection import train_test_split
tr_x,v_x,tr_y,V_y= train_test_split(ov_train_x, ov_train_y, test_size=0.2)

print(len(v_x))
# Out:
# 2020

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import LeakyReLU
model=keras.models.Sequential([
    keras.layers.Dense(300,activation="selu",input_shape=(tr_x.shape[1],)),
    keras.layers.Dense(200,activation="selu",kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(100,activation="selu",kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(2,activation="softmax")
])
epochs=100
optimizers=keras.optimizers.SGD(clipvalue=1.0)
def exp_decay(lr0,s):
    def exp_decay_fn(epcohs):
        return lr0*0.1**(epochs/s)
    return exp_decay_fn

exp_decay_fn=exp_decay(lr0=0.1,s=20)
lr_sch=keras.callbacks.LearningRateScheduler(exp_decay_fn)
lr_sch2=keras.callbacks.ReduceLROnPlateau(factor=0.5,patience=5)
model.compile(loss="sparse_categorical_crossentropy",optimizer=optimizers,metrics=["accuracy"])
history=model.fit(tr_x,tr_y,epochs=100,callbacks=[lr_sch],validation_data=(v_x,V_y))
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot()
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()
predict = np.argmax(model.predict(trns_y),axis=1)
print(confusion_matrix(testy['new1'], predict))
print(classification_report(testy['new1'], predict))
# Out:
# Epoch 1/100
# 253/253 [==============================] - 5s 6ms/step - loss: 4.4176 - accuracy: 0.5020 - val_loss: 4.4074 - val_accuracy: 0.5144 - lr: 1.0000e-06
# Epoch 2/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4173 - accuracy: 0.5021 - val_loss: 4.4072 - val_accuracy: 0.5149 - lr: 1.0000e-06
# Epoch 3/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4169 - accuracy: 0.5021 - val_loss: 4.4070 - val_accuracy: 0.5144 - lr: 1.0000e-06
# Epoch 4/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4166 - accuracy: 0.5019 - val_loss: 4.4069 - val_accuracy: 0.5139 - lr: 1.0000e-06
# Epoch 5/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4163 - accuracy: 0.5019 - val_loss: 4.4067 - val_accuracy: 0.5139 - lr: 1.0000e-06
# Epoch 6/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4160 - accuracy: 0.5015 - val_loss: 4.4065 - val_accuracy: 0.5149 - lr: 1.0000e-06
# Epoch 7/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4156 - accuracy: 0.5019 - val_loss: 4.4063 - val_accuracy: 0.5144 - lr: 1.0000e-06
# Epoch 8/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4153 - accuracy: 0.5016 - val_loss: 4.4062 - val_accuracy: 0.5144 - lr: 1.0000e-06
# Epoch 9/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4150 - accuracy: 0.5016 - val_loss: 4.4060 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 10/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4147 - accuracy: 0.5014 - val_loss: 4.4058 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 11/100
# 253/253 [==============================] - 2s 6ms/step - loss: 4.4144 - accuracy: 0.5016 - val_loss: 4.4057 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 12/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4141 - accuracy: 0.5015 - val_loss: 4.4055 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 13/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4138 - accuracy: 0.5016 - val_loss: 4.4054 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 14/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4135 - accuracy: 0.5014 - val_loss: 4.4052 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 15/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4132 - accuracy: 0.5011 - val_loss: 4.4051 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 16/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4129 - accuracy: 0.5011 - val_loss: 4.4049 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 17/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4127 - accuracy: 0.5015 - val_loss: 4.4048 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 18/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4124 - accuracy: 0.5016 - val_loss: 4.4046 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 19/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4121 - accuracy: 0.5014 - val_loss: 4.4045 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 20/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4118 - accuracy: 0.5014 - val_loss: 4.4044 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 21/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4116 - accuracy: 0.5016 - val_loss: 4.4042 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 22/100
# 253/253 [==============================] - 2s 8ms/step - loss: 4.4113 - accuracy: 0.5014 - val_loss: 4.4041 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 23/100
# 253/253 [==============================] - 3s 11ms/step - loss: 4.4110 - accuracy: 0.5011 - val_loss: 4.4040 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 24/100
# 253/253 [==============================] - 1s 6ms/step - loss: 4.4108 - accuracy: 0.5004 - val_loss: 4.4039 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 25/100
# 253/253 [==============================] - 2s 6ms/step - loss: 4.4105 - accuracy: 0.5004 - val_loss: 4.4038 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 26/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4103 - accuracy: 0.5007 - val_loss: 4.4037 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 27/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4100 - accuracy: 0.5007 - val_loss: 4.4036 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 28/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4098 - accuracy: 0.5007 - val_loss: 4.4035 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 29/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4095 - accuracy: 0.5009 - val_loss: 4.4034 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 30/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4093 - accuracy: 0.5006 - val_loss: 4.4033 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 31/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4091 - accuracy: 0.5007 - val_loss: 4.4032 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 32/100
# 253/253 [==============================] - 2s 6ms/step - loss: 4.4088 - accuracy: 0.5002 - val_loss: 4.4031 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 33/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4086 - accuracy: 0.5004 - val_loss: 4.4030 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 34/100
# 253/253 [==============================] - 2s 9ms/step - loss: 4.4084 - accuracy: 0.5004 - val_loss: 4.4029 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 35/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4081 - accuracy: 0.5002 - val_loss: 4.4028 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 36/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4079 - accuracy: 0.5001 - val_loss: 4.4027 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 37/100
# 253/253 [==============================] - 2s 8ms/step - loss: 4.4077 - accuracy: 0.5000 - val_loss: 4.4026 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 38/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4075 - accuracy: 0.5000 - val_loss: 4.4025 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 39/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4072 - accuracy: 0.5006 - val_loss: 4.4024 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 40/100
# 253/253 [==============================] - 3s 10ms/step - loss: 4.4070 - accuracy: 0.5006 - val_loss: 4.4023 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 41/100
# 253/253 [==============================] - 3s 12ms/step - loss: 4.4068 - accuracy: 0.5006 - val_loss: 4.4023 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 42/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4066 - accuracy: 0.4999 - val_loss: 4.4022 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 43/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4063 - accuracy: 0.4991 - val_loss: 4.4021 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 44/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4061 - accuracy: 0.4989 - val_loss: 4.4020 - val_accuracy: 0.5134 - lr: 1.0000e-06
# Epoch 45/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4059 - accuracy: 0.4989 - val_loss: 4.4019 - val_accuracy: 0.5129 - lr: 1.0000e-06
# Epoch 46/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4057 - accuracy: 0.4986 - val_loss: 4.4019 - val_accuracy: 0.5124 - lr: 1.0000e-06
# Epoch 47/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4055 - accuracy: 0.4984 - val_loss: 4.4018 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 48/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4053 - accuracy: 0.4976 - val_loss: 4.4017 - val_accuracy: 0.5119 - lr: 1.0000e-06
# Epoch 49/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4051 - accuracy: 0.4975 - val_loss: 4.4016 - val_accuracy: 0.5104 - lr: 1.0000e-06
# Epoch 50/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4049 - accuracy: 0.4976 - val_loss: 4.4016 - val_accuracy: 0.5094 - lr: 1.0000e-06
# Epoch 51/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4046 - accuracy: 0.4968 - val_loss: 4.4015 - val_accuracy: 0.5094 - lr: 1.0000e-06
# Epoch 52/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4044 - accuracy: 0.4957 - val_loss: 4.4014 - val_accuracy: 0.5084 - lr: 1.0000e-06
# Epoch 53/100
# 253/253 [==============================] - 2s 7ms/step - loss: 4.4042 - accuracy: 0.4952 - val_loss: 4.4013 - val_accuracy: 0.5069 - lr: 1.0000e-06
# Epoch 54/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.4040 - accuracy: 0.4942 - val_loss: 4.4013 - val_accuracy: 0.5050 - lr: 1.0000e-06
# Epoch 55/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4038 - accuracy: 0.4933 - val_loss: 4.4012 - val_accuracy: 0.5035 - lr: 1.0000e-06
# Epoch 56/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4036 - accuracy: 0.4932 - val_loss: 4.4011 - val_accuracy: 0.5035 - lr: 1.0000e-06
# Epoch 57/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4034 - accuracy: 0.4918 - val_loss: 4.4011 - val_accuracy: 0.5020 - lr: 1.0000e-06
# Epoch 58/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4032 - accuracy: 0.4894 - val_loss: 4.4010 - val_accuracy: 0.4990 - lr: 1.0000e-06
# Epoch 59/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4030 - accuracy: 0.4870 - val_loss: 4.4009 - val_accuracy: 0.4980 - lr: 1.0000e-06
# Epoch 60/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4028 - accuracy: 0.4859 - val_loss: 4.4009 - val_accuracy: 0.4960 - lr: 1.0000e-06
# Epoch 61/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4026 - accuracy: 0.4844 - val_loss: 4.4008 - val_accuracy: 0.4941 - lr: 1.0000e-06
# Epoch 62/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4024 - accuracy: 0.4818 - val_loss: 4.4007 - val_accuracy: 0.4936 - lr: 1.0000e-06
# Epoch 63/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4022 - accuracy: 0.4816 - val_loss: 4.4007 - val_accuracy: 0.4926 - lr: 1.0000e-06
# Epoch 64/100
# 253/253 [==============================] - 1s 6ms/step - loss: 4.4020 - accuracy: 0.4807 - val_loss: 4.4006 - val_accuracy: 0.4921 - lr: 1.0000e-06
# Epoch 65/100
# 253/253 [==============================] - 1s 6ms/step - loss: 4.4019 - accuracy: 0.4795 - val_loss: 4.4006 - val_accuracy: 0.4906 - lr: 1.0000e-06
# Epoch 66/100
# 253/253 [==============================] - 2s 6ms/step - loss: 4.4017 - accuracy: 0.4790 - val_loss: 4.4005 - val_accuracy: 0.4886 - lr: 1.0000e-06
# Epoch 67/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4015 - accuracy: 0.4781 - val_loss: 4.4004 - val_accuracy: 0.4886 - lr: 1.0000e-06
# Epoch 68/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4013 - accuracy: 0.4775 - val_loss: 4.4004 - val_accuracy: 0.4876 - lr: 1.0000e-06
# Epoch 69/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4011 - accuracy: 0.4767 - val_loss: 4.4003 - val_accuracy: 0.4851 - lr: 1.0000e-06
# Epoch 70/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4009 - accuracy: 0.4760 - val_loss: 4.4003 - val_accuracy: 0.4856 - lr: 1.0000e-06
# Epoch 71/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4007 - accuracy: 0.4756 - val_loss: 4.4002 - val_accuracy: 0.4851 - lr: 1.0000e-06
# Epoch 72/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4005 - accuracy: 0.4750 - val_loss: 4.4001 - val_accuracy: 0.4847 - lr: 1.0000e-06
# Epoch 73/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4004 - accuracy: 0.4749 - val_loss: 4.4001 - val_accuracy: 0.4842 - lr: 1.0000e-06
# Epoch 74/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4002 - accuracy: 0.4740 - val_loss: 4.4000 - val_accuracy: 0.4827 - lr: 1.0000e-06
# Epoch 75/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.4000 - accuracy: 0.4738 - val_loss: 4.4000 - val_accuracy: 0.4827 - lr: 1.0000e-06
# Epoch 76/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3998 - accuracy: 0.4734 - val_loss: 4.3999 - val_accuracy: 0.4822 - lr: 1.0000e-06
# Epoch 77/100
# 253/253 [==============================] - 1s 6ms/step - loss: 4.3997 - accuracy: 0.4731 - val_loss: 4.3998 - val_accuracy: 0.4822 - lr: 1.0000e-06
# Epoch 78/100
# 253/253 [==============================] - 3s 13ms/step - loss: 4.3995 - accuracy: 0.4730 - val_loss: 4.3998 - val_accuracy: 0.4817 - lr: 1.0000e-06
# Epoch 79/100
# 253/253 [==============================] - 1s 5ms/step - loss: 4.3993 - accuracy: 0.4725 - val_loss: 4.3997 - val_accuracy: 0.4797 - lr: 1.0000e-06
# Epoch 80/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3992 - accuracy: 0.4726 - val_loss: 4.3997 - val_accuracy: 0.4797 - lr: 1.0000e-06
# Epoch 81/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3990 - accuracy: 0.4717 - val_loss: 4.3996 - val_accuracy: 0.4782 - lr: 1.0000e-06
# Epoch 82/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3989 - accuracy: 0.4714 - val_loss: 4.3996 - val_accuracy: 0.4777 - lr: 1.0000e-06
# Epoch 83/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3987 - accuracy: 0.4712 - val_loss: 4.3995 - val_accuracy: 0.4767 - lr: 1.0000e-06
# Epoch 84/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3986 - accuracy: 0.4709 - val_loss: 4.3995 - val_accuracy: 0.4752 - lr: 1.0000e-06
# Epoch 85/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3985 - accuracy: 0.4710 - val_loss: 4.3994 - val_accuracy: 0.4748 - lr: 1.0000e-06
# Epoch 86/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3984 - accuracy: 0.4708 - val_loss: 4.3994 - val_accuracy: 0.4743 - lr: 1.0000e-06
# Epoch 87/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3983 - accuracy: 0.4704 - val_loss: 4.3993 - val_accuracy: 0.4738 - lr: 1.0000e-06
# Epoch 88/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3981 - accuracy: 0.4704 - val_loss: 4.3993 - val_accuracy: 0.4738 - lr: 1.0000e-06
# Epoch 89/100
# 253/253 [==============================] - 2s 6ms/step - loss: 4.3980 - accuracy: 0.4700 - val_loss: 4.3992 - val_accuracy: 0.4752 - lr: 1.0000e-06
# Epoch 90/100
# 253/253 [==============================] - 1s 6ms/step - loss: 4.3979 - accuracy: 0.4700 - val_loss: 4.3992 - val_accuracy: 0.4733 - lr: 1.0000e-06
# Epoch 91/100
# 253/253 [==============================] - 2s 6ms/step - loss: 4.3979 - accuracy: 0.4697 - val_loss: 4.3991 - val_accuracy: 0.4733 - lr: 1.0000e-06
# Epoch 92/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3978 - accuracy: 0.4699 - val_loss: 4.3991 - val_accuracy: 0.4733 - lr: 1.0000e-06
# Epoch 93/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3977 - accuracy: 0.4696 - val_loss: 4.3990 - val_accuracy: 0.4743 - lr: 1.0000e-06
# Epoch 94/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3976 - accuracy: 0.4697 - val_loss: 4.3990 - val_accuracy: 0.4743 - lr: 1.0000e-06
# Epoch 95/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3975 - accuracy: 0.4691 - val_loss: 4.3989 - val_accuracy: 0.4738 - lr: 1.0000e-06
# Epoch 96/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3974 - accuracy: 0.4687 - val_loss: 4.3989 - val_accuracy: 0.4733 - lr: 1.0000e-06
# Epoch 97/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3973 - accuracy: 0.4686 - val_loss: 4.3988 - val_accuracy: 0.4743 - lr: 1.0000e-06
# Epoch 98/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3972 - accuracy: 0.4684 - val_loss: 4.3988 - val_accuracy: 0.4743 - lr: 1.0000e-06
# Epoch 99/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3972 - accuracy: 0.4684 - val_loss: 4.3987 - val_accuracy: 0.4743 - lr: 1.0000e-06
# Epoch 100/100
# 253/253 [==============================] - 1s 4ms/step - loss: 4.3971 - accuracy: 0.4681 - val_loss: 4.3987 - val_accuracy: 0.4728 - lr: 1.0000e-06
# 18/18 [==============================] - 0s 2ms/step
# [[ 10 555]
#  [  1   4]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.02      0.03       565
#          1.0       0.01      0.80      0.01         5
#
#     accuracy                           0.02       570
#    macro avg       0.46      0.41      0.02       570
# weighted avg       0.90      0.02      0.03       570

# %%
model=keras.models.Sequential([
    keras.layers.Dense(300,activation="swish",input_shape=(tr_x.shape[1],)),
    keras.layers.Dense(200,activation="swish",kernel_initializer="he_normal"),
    keras.layers.Dense(100,activation="swish",kernel_initializer="he_normal"),
    keras.layers.Dense(2,activation="softmax")
])

optimizers=tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name="Adam"

)
lr_sch2=keras.callbacks.ReduceLROnPlateau(factor=0.5,patience=5)
model.compile(loss="sparse_categorical_crossentropy",optimizer=optimizers,metrics=["accuracy"])
history=model.fit(tr_x,tr_y,epochs=50,validation_data=(v_x,V_y),callbacks=[lr_sch2])
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot()
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()
predict = np.argmax(model.predict(trns_y),axis=1)
print(confusion_matrix(testy['new1'], predict))
print(classification_report(testy['new1'], predict))
# Out:
# Epoch 1/50
# 253/253 [==============================] - 3s 8ms/step - loss: 0.6658 - accuracy: 0.5847 - val_loss: 0.6631 - val_accuracy: 0.5510 - lr: 0.0010
# Epoch 2/50
# 253/253 [==============================] - 1s 6ms/step - loss: 0.6449 - accuracy: 0.6053 - val_loss: 0.6527 - val_accuracy: 0.5515 - lr: 0.0010
# Epoch 3/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.6325 - accuracy: 0.6286 - val_loss: 0.6384 - val_accuracy: 0.6104 - lr: 0.0010
# Epoch 4/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.6200 - accuracy: 0.6423 - val_loss: 0.6146 - val_accuracy: 0.7371 - lr: 0.0010
# Epoch 5/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.6058 - accuracy: 0.6619 - val_loss: 0.6056 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 6/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.6001 - accuracy: 0.6830 - val_loss: 0.6162 - val_accuracy: 0.6441 - lr: 0.0010
# Epoch 7/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.5936 - accuracy: 0.6743 - val_loss: 0.5798 - val_accuracy: 0.7579 - lr: 0.0010
# Epoch 8/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.5534 - accuracy: 0.7252 - val_loss: 0.5267 - val_accuracy: 0.7876 - lr: 0.0010
# Epoch 9/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.5318 - accuracy: 0.7480 - val_loss: 0.5028 - val_accuracy: 0.8050 - lr: 0.0010
# Epoch 10/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4947 - accuracy: 0.7717 - val_loss: 0.4817 - val_accuracy: 0.7698 - lr: 0.0010
# Epoch 11/50
# 253/253 [==============================] - 2s 6ms/step - loss: 0.4876 - accuracy: 0.7849 - val_loss: 0.4989 - val_accuracy: 0.7748 - lr: 0.0010
# Epoch 12/50
# 253/253 [==============================] - 2s 7ms/step - loss: 0.4645 - accuracy: 0.7950 - val_loss: 0.4464 - val_accuracy: 0.8248 - lr: 0.0010
# Epoch 13/50
# 253/253 [==============================] - 2s 7ms/step - loss: 0.4550 - accuracy: 0.7999 - val_loss: 0.5370 - val_accuracy: 0.7510 - lr: 0.0010
# Epoch 14/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4564 - accuracy: 0.7960 - val_loss: 0.4460 - val_accuracy: 0.8119 - lr: 0.0010
# Epoch 15/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4481 - accuracy: 0.8035 - val_loss: 0.4419 - val_accuracy: 0.8213 - lr: 0.0010
# Epoch 16/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4375 - accuracy: 0.8108 - val_loss: 0.4457 - val_accuracy: 0.8129 - lr: 0.0010
# Epoch 17/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4471 - accuracy: 0.7967 - val_loss: 0.4307 - val_accuracy: 0.8292 - lr: 0.0010
# Epoch 18/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4305 - accuracy: 0.8116 - val_loss: 0.4554 - val_accuracy: 0.8149 - lr: 0.0010
# Epoch 19/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4239 - accuracy: 0.8205 - val_loss: 0.4426 - val_accuracy: 0.7950 - lr: 0.0010
# Epoch 20/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.4149 - accuracy: 0.8192 - val_loss: 0.4298 - val_accuracy: 0.8099 - lr: 0.0010
# Epoch 21/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.4150 - accuracy: 0.8204 - val_loss: 0.4112 - val_accuracy: 0.8351 - lr: 0.0010
# Epoch 22/50
# 253/253 [==============================] - 3s 12ms/step - loss: 0.4073 - accuracy: 0.8251 - val_loss: 0.4185 - val_accuracy: 0.7995 - lr: 0.0010
# Epoch 23/50
# 253/253 [==============================] - 2s 8ms/step - loss: 0.4173 - accuracy: 0.8149 - val_loss: 0.3922 - val_accuracy: 0.8411 - lr: 0.0010
# Epoch 24/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4028 - accuracy: 0.8271 - val_loss: 0.4132 - val_accuracy: 0.8272 - lr: 0.0010
# Epoch 25/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3943 - accuracy: 0.8297 - val_loss: 0.3842 - val_accuracy: 0.8436 - lr: 0.0010
# Epoch 26/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3945 - accuracy: 0.8314 - val_loss: 0.3920 - val_accuracy: 0.8416 - lr: 0.0010
# Epoch 27/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4897 - accuracy: 0.8252 - val_loss: 0.4176 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 28/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3968 - accuracy: 0.8328 - val_loss: 0.4418 - val_accuracy: 0.7916 - lr: 0.0010
# Epoch 29/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3882 - accuracy: 0.8359 - val_loss: 0.3763 - val_accuracy: 0.8485 - lr: 0.0010
# Epoch 30/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3873 - accuracy: 0.8308 - val_loss: 0.4074 - val_accuracy: 0.8005 - lr: 0.0010
# Epoch 31/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3762 - accuracy: 0.8410 - val_loss: 0.3705 - val_accuracy: 0.8564 - lr: 0.0010
# Epoch 32/50
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3692 - accuracy: 0.8437 - val_loss: 0.3654 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 33/50
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3719 - accuracy: 0.8431 - val_loss: 0.3842 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 34/50
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3648 - accuracy: 0.8457 - val_loss: 0.3553 - val_accuracy: 0.8609 - lr: 0.0010
# Epoch 35/50
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3544 - accuracy: 0.8509 - val_loss: 0.3433 - val_accuracy: 0.8698 - lr: 0.0010
# Epoch 36/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3543 - accuracy: 0.8512 - val_loss: 0.4057 - val_accuracy: 0.8347 - lr: 0.0010
# Epoch 37/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3518 - accuracy: 0.8537 - val_loss: 0.3618 - val_accuracy: 0.8535 - lr: 0.0010
# Epoch 38/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3446 - accuracy: 0.8535 - val_loss: 0.3860 - val_accuracy: 0.8351 - lr: 0.0010
# Epoch 39/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3444 - accuracy: 0.8578 - val_loss: 0.4000 - val_accuracy: 0.8272 - lr: 0.0010
# Epoch 40/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3399 - accuracy: 0.8589 - val_loss: 0.3187 - val_accuracy: 0.8708 - lr: 0.0010
# Epoch 41/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3307 - accuracy: 0.8665 - val_loss: 0.3292 - val_accuracy: 0.8673 - lr: 0.0010
# Epoch 42/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.9669 - accuracy: 0.8590 - val_loss: 0.4120 - val_accuracy: 0.8054 - lr: 0.0010
# Epoch 43/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3311 - accuracy: 0.8634 - val_loss: 0.3392 - val_accuracy: 0.8599 - lr: 0.0010
# Epoch 44/50
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3227 - accuracy: 0.8673 - val_loss: 0.3381 - val_accuracy: 0.8579 - lr: 0.0010
# Epoch 45/50
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3214 - accuracy: 0.8651 - val_loss: 0.3065 - val_accuracy: 0.8713 - lr: 0.0010
# Epoch 46/50
# 253/253 [==============================] - 1s 6ms/step - loss: 0.3237 - accuracy: 0.8645 - val_loss: 0.3122 - val_accuracy: 0.8728 - lr: 0.0010
# Epoch 47/50
# 253/253 [==============================] - 2s 8ms/step - loss: 0.3202 - accuracy: 0.8660 - val_loss: 0.3581 - val_accuracy: 0.8550 - lr: 0.0010
# Epoch 48/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3232 - accuracy: 0.8632 - val_loss: 0.2965 - val_accuracy: 0.8772 - lr: 0.0010
# Epoch 49/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3155 - accuracy: 0.8691 - val_loss: 0.3151 - val_accuracy: 0.8698 - lr: 0.0010
# Epoch 50/50
# 253/253 [==============================] - 1s 4ms/step - loss: 0.3145 - accuracy: 0.8702 - val_loss: 0.3140 - val_accuracy: 0.8767 - lr: 0.0010
# 18/18 [==============================] - 0s 2ms/step
# [[565   0]
#  [  5   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00       565
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570

# %%
from xgboost import XGBClassifier
scale_pos_weight = [2,0.99,0.60,0.50,0.33,0.20,0.10]
for i in scale_pos_weight:
    print('scale_pos_weight = {}: '.format(i))
    clf = XGBClassifier(scale_pos_weight=i)
    clf.fit(ov_train_x, ov_train_y)
    predict = clf.predict(trns_y)
    cm = confusion_matrix(testy['new1'], predict)
    auc=metrics.roc_auc_score(testy['new1'], predict)
    print('Confusion Matrix: \n', cm)
    print('metrics: \n',classification_report(testy['new1'], predict))
    print('AUC of test set: {:.2f} \n'.format(metrics.roc_auc_score(testy['new1'], predict)))
# Out:
# scale_pos_weight = 2:
# Confusion Matrix:
#  [[184 381]
#  [  2   3]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.33      0.49       565
#          1.0       0.01      0.60      0.02         5
#
#     accuracy                           0.33       570
#    macro avg       0.50      0.46      0.25       570
# weighted avg       0.98      0.33      0.49       570
#
# AUC of test set: 0.46
#
# scale_pos_weight = 0.99:
# Confusion Matrix:
#  [[422 143]
#  [  3   2]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.75      0.85       565
#          1.0       0.01      0.40      0.03         5
#
#     accuracy                           0.74       570
#    macro avg       0.50      0.57      0.44       570
# weighted avg       0.98      0.74      0.85       570
#
# AUC of test set: 0.57
#
# scale_pos_weight = 0.6:
# Confusion Matrix:
#  [[509  56]
#  [  3   2]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.90      0.95       565
#          1.0       0.03      0.40      0.06         5
#
#     accuracy                           0.90       570
#    macro avg       0.51      0.65      0.50       570
# weighted avg       0.99      0.90      0.94       570
#
# AUC of test set: 0.65
#
# scale_pos_weight = 0.5:
# Confusion Matrix:
#  [[388 177]
#  [  3   2]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.69      0.81       565
#          1.0       0.01      0.40      0.02         5
#
#     accuracy                           0.68       570
#    macro avg       0.50      0.54      0.42       570
# weighted avg       0.98      0.68      0.80       570
#
# AUC of test set: 0.54
#
# scale_pos_weight = 0.33:
# Confusion Matrix:
#  [[452 113]
#  [  3   2]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.80      0.89       565
#          1.0       0.02      0.40      0.03         5
#
#     accuracy                           0.80       570
#    macro avg       0.51      0.60      0.46       570
# weighted avg       0.98      0.80      0.88       570
#
# AUC of test set: 0.60
#
# scale_pos_weight = 0.2:
# Confusion Matrix:
#  [[456 109]
#  [  3   2]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.81      0.89       565
#          1.0       0.02      0.40      0.03         5
#
#     accuracy                           0.80       570
#    macro avg       0.51      0.60      0.46       570
# weighted avg       0.98      0.80      0.88       570
#
# AUC of test set: 0.60
#
# scale_pos_weight = 0.1:
# Confusion Matrix:
#  [[508  57]
#  [  5   0]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.90      0.94       565
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.89       570
#    macro avg       0.50      0.45      0.47       570
# weighted avg       0.98      0.89      0.93       570
#
# AUC of test set: 0.45

# %%
scale_pos_weight = [0.33]
print('scale_pos_weight = 0.33 ')
clf = XGBClassifier(scale_pos_weight= 0.33)
clf.fit(ov_train_x, ov_train_y)
predict = clf.predict(trns_y)
cm = confusion_matrix(testy['new1'], predict)
auc=metrics.roc_auc_score(testy['new1'], predict)
print('Confusion Matrix: \n', cm)
print('metrics: \n',classification_report(testy['new1'], predict))
print('AUC of test set: {:.2f} \n'.format(metrics.roc_auc_score(testy['new1'], predict)))
# Out:
# scale_pos_weight = 0.33
# Confusion Matrix:
#  [[452 113]
#  [  3   2]]
# metrics:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.80      0.89       565
#          1.0       0.02      0.40      0.03         5
#
#     accuracy                           0.80       570
#    macro avg       0.51      0.60      0.46       570
# weighted avg       0.98      0.80      0.88       570
#
# AUC of test set: 0.60
